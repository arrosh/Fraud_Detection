# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import random
from sklearn.preprocessing import scale

# %%
df = pd.read_csv("~/Downloads/kaggle/creditcard.csv", low_memory=False)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 13935    24718.0 -0.697112  1.104082 -0.545003 -0.841362  2.325786  3.240487
# 207564  136733.0  1.900202 -0.351976 -0.557703  1.211511 -0.330240 -0.074231
# 158669  111618.0  2.092010 -0.852087 -1.027656 -1.785257 -0.348426  0.155785
# 91297    63401.0  1.178238  0.025634 -0.329076  0.895270  0.748480  1.154075
# 84437    60304.0 -2.177002 -1.271227  1.566449  0.805028  0.884398 -0.979194
#
#               V7        V8        V9  ...         V21       V22       V23  \
# 13935  -0.332560  1.282851  0.612769  ...   -0.413091 -1.211635  0.043900
# 207564 -0.468576  0.020432  1.027190  ...    0.209182  0.631417  0.019903
# 158669 -0.859627  0.142866  2.177542  ...    0.232563  0.961716 -0.017013
# 91297  -0.005074  0.215839  0.097472  ...   -0.139540 -0.254135 -0.321848
# 84437  -1.254596  0.821391  0.323318  ...    0.390542  0.423305  0.043680
#
#              V24       V25       V26       V27       V28  Amount  Class
# 13935   0.872975 -0.001558  0.050701  0.092547  0.010160   14.99      0
# 207564 -0.741742 -0.047303 -0.518811  0.046209 -0.029692   57.00      0
# 158669 -0.080213  0.086401 -0.062440  0.030224 -0.057449    0.76      0
# 91297  -1.679353  0.862126 -0.227757  0.029459 -0.005072   42.35      0
# 84437   0.080798 -0.795020 -0.662190  0.162949 -0.177306    1.00      0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#            ...                 V21           V22           V23           V24  \
# count      ...        2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean       ...        1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std        ...        7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min        ...       -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%        ...       -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%        ...       -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%        ...        1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max        ...        2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
frauds = df.loc[df["Class"] == 1]
non_frauds = df.loc[df["Class"] == 0]
print(len(frauds))
print(len(non_frauds))
# Out:
# 492
# 284315

# %%
count_classes = pd.value_counts(df['Class'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Fraud class histogram")
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = frauds.plot.scatter(x="Amount", y="Class", color="orange", label="Fraud")
non_frauds.plot.scatter(x="Amount", y="Class", color="Blue", label="Normal", ax=ax)
plt.show()

# %%
X=df.iloc[:, :-1].values
y=df["Class"].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0, C=1e5)
classifier.fit(X_train, y_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=0,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = classifier.predict(X_test)
print(y_pred)
print(len(y_pred))
# Out:
# [0 0 0 ... 0 0 0]
# 99683

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm=confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[99477    36]
#  [   75    95]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     99513
#            1       0.73      0.56      0.63       170
#
#    micro avg       1.00      1.00      1.00     99683
#    macro avg       0.86      0.78      0.82     99683
# weighted avg       1.00      1.00      1.00     99683
